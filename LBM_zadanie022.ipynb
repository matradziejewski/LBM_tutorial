# %% [markdown]
# # Ścieżka wirów Kármána
#
# Opływ rzeczywistej cieczy przez nieskończony cylinder (lub koło w 2d) dla małych liczb Re jest laminarny i pole prędkości przypomina przepływ potencjalny. Jednak zwiększając liczbę Re pojawia się para wirów za przeszkodą, które wraz ze zwiększająca się Re tracą stabilność na rzecz stanu oscylacyjnego.
#
# - https://www.youtube.com/watch?v=PJW341Zc9TE
# - https://www.youtube.com/watch?v=JI0M1gVNhbw
# - https://www.youtube.com/watch?v=_AJgEa2dbJU
#
# Zbadajmy jak zachowuje sie taki układ.
#
#
# ###Wykonaj:
#
# 1. Uruchom poniższą symulacje dla parametrów:
#
#  - $nu_{LB}=0.01$: parametr `-visc=0.01`
#  - rozmiaru siatki układu $nx=126$ oraz $ny=510$
#
#  W tym przypadku napędzimy układ siłą objętościowa (gęstością siły), którą w kodzie zadajemy przez np.:
#
#     self.add_body_force((15e-7, 0.0))
#
#  Poniższa symulacja zawiera w połowie wysokości dysk o średnicy 20[lu].
#
# 2. Zbadaj zachowanie się układu dla kilku wartości siły objętościowej działająca na ciecz. Zwiększająć siłę zwiększamy   prędkość przepływu a tym samym Re.
#
#   W każdym przypadku oblicz liczbę Reynoldsa dla w/w układu, jako rozmiar charakterystyczny przyjmij rozmiar   przeszkody w jednostkach sieci. Prędkość charakterystyczna niech bedzie maksymalną prędkością w układzie.
#
#
#   - $0.5\times 10^{-7}$: $v_{max}=?$, $Re=?$, zawirowanie za przeszkodą?, złamanie symetrii w $y$?, ustala się przepływ stały|okresowy|nieokresowy
#   - $5 \times 10^{-7}$: $v_{max}=?$, $Re=?$, zawirowanie za przeszkodą?, złamanie symetrii w $y$?, ustala się przepływ stały|okresowy|nieokresowy
#   - $15 \times 10^{-7}$: $v_{max}=?$, $Re=?$, zawirowanie za przeszkodą?, złamanie symetrii w $y$?, ustala się przepływ stały|okresowy|nieokresowy
#   - $20 \times 10^{-7}$: $v_{max}=?$, $Re=?$, zawirowanie za przeszkodą?, złamanie symetrii w $y$?, ustala się przepływ stały|okresowy|nieokresowy

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sys,os
sys.path.append('./sailfish/')
if not (os.path.isdir('data') or os.path.islink('data')):
    os.mkdir('data')

# %%
# %%writefile karman.py
import numpy as np
from sailfish.subdomain import Subdomain2D
from sailfish.node_type import NTFullBBWall
from sailfish.controller import LBSimulationController
from sailfish.lb_single import LBFluidSim, LBForcedSim

class MyBlock(Subdomain2D):
    max_v = 0.1

    def boundary_conditions(self, hx, hy):
       
        diam = 20
        x0 = 2 * diam
        y0 = self.gy / 2
        
        self.set_node(hy == 0, NTFullBBWall)
        self.set_node(hy == self.gy - 1, NTFullBBWall)
        cylinder_map = np.square(hx - x0) + np.square(hy - y0) < diam**2 / 4.0
        
        not_wall = (hy > 0) & (hy < self.gy - 1)
        
        self.set_node(cylinder_map, NTFullBBWall)
     
        
    def initial_conditions(self, sim, hx, hy):
        sim.rho[:] = 1.0

class MySim(LBFluidSim, LBForcedSim):
    
    subdomain = MyBlock

    def __init__(self, config):
        super(MySim, self).__init__(config)
        self.add_body_force((20e-7, 0.0))

LBSimulationController(MySim).run()
# Out:
# Overwriting karman.py

# %%
# %%sh
# rm data/karman*npz
# export PYTHONPATH=$PWD/sailfish/
# python karman.py --max_iters=100000 --from=0000 --every=10000 \
#  --lat_nx=510 --lat_ny=126 --model=mrt \
#  --visc=0.01 --periodic_x\
#  --output=data/karman --output_format=npy
# Out:
# [   775  INFO Master/rider] Machine master starting with PID 15131 at 2015-01-27 06:05:24 UTC
# [   790  INFO Master/rider] Sailfish version: 9dd8b711d44c9e11614f7b760f32bdbbfa340064
# [   790  INFO Master/rider] Handling subdomains: [0]
# [   791  INFO Master/rider] Subdomain -> GPU map: {0: 0}
# [   792  INFO Master/rider] Selected backend: cuda
# [   846  INFO Subdomain/0] Initializing subdomain.
# [   847  INFO Subdomain/0] Required memory:
# [   847  INFO Subdomain/0] . distributions: 4 MiB
# [   847  INFO Subdomain/0] . fields: 0 MiB
# [   916  INFO Subdomain/0] On-GPU invalid result check disabled as the device does not support all required features.
# [  3398  INFO Subdomain/0] Starting simulation.
# [  3635  INFO Subdomain/0] iteration:2000  speed:534.11 MLUPS
# [  3753  INFO Subdomain/0] iteration:3000  speed:527.41 MLUPS
# [  3870  INFO Subdomain/0] iteration:4000  speed:533.91 MLUPS
# [  3988  INFO Subdomain/0] iteration:5000  speed:535.05 MLUPS
# [  4106  INFO Subdomain/0] iteration:6000  speed:535.45 MLUPS
# [  4223  INFO Subdomain/0] iteration:7000  speed:534.79 MLUPS
# [  4341  INFO Subdomain/0] iteration:8000  speed:535.07 MLUPS
# [  4459  INFO Subdomain/0] iteration:9000  speed:534.91 MLUPS
# [  4576  INFO Subdomain/0] iteration:10000  speed:534.61 MLUPS
# [  4748  INFO Subdomain/0] iteration:11000  speed:365.80 MLUPS
# [  4866  INFO Subdomain/0] iteration:12000  speed:534.38 MLUPS
# [  4984  INFO Subdomain/0] iteration:13000  speed:534.93 MLUPS
# [  5101  INFO Subdomain/0] iteration:14000  speed:534.40 MLUPS
# [  5219  INFO Subdomain/0] iteration:15000  speed:534.95 MLUPS
# [  5337  INFO Subdomain/0] iteration:16000  speed:534.30 MLUPS
# [  5455  INFO Subdomain/0] iteration:17000  speed:534.38 MLUPS
# [  5572  INFO Subdomain/0] iteration:18000  speed:535.08 MLUPS
# [  5690  INFO Subdomain/0] iteration:19000  speed:534.95 MLUPS
# [  5808  INFO Subdomain/0] iteration:20000  speed:534.20 MLUPS
# [  5980  INFO Subdomain/0] iteration:21000  speed:364.51 MLUPS
# [  6098  INFO Subdomain/0] iteration:22000  speed:534.41 MLUPS
# [  6216  INFO Subdomain/0] iteration:23000  speed:534.86 MLUPS
# [  6334  INFO Subdomain/0] iteration:24000  speed:534.45 MLUPS
# [  6451  INFO Subdomain/0] iteration:25000  speed:534.23 MLUPS
# [  6569  INFO Subdomain/0] iteration:26000  speed:535.19 MLUPS
# [  6687  INFO Subdomain/0] iteration:27000  speed:535.22 MLUPS
# [  6804  INFO Subdomain/0] iteration:28000  speed:536.31 MLUPS
# [  6921  INFO Subdomain/0] iteration:29000  speed:536.13 MLUPS
# [  7039  INFO Subdomain/0] iteration:30000  speed:535.69 MLUPS
# [  7215  INFO Subdomain/0] iteration:31000  speed:358.16 MLUPS
# [  7332  INFO Subdomain/0] iteration:32000  speed:536.13 MLUPS
# [  7449  INFO Subdomain/0] iteration:33000  speed:536.13 MLUPS
# [  7567  INFO Subdomain/0] iteration:34000  speed:536.35 MLUPS
# [  7684  INFO Subdomain/0] iteration:35000  speed:535.84 MLUPS
# [  7802  INFO Subdomain/0] iteration:36000  speed:535.70 MLUPS
# [  7919  INFO Subdomain/0] iteration:37000  speed:534.90 MLUPS
# [  8037  INFO Subdomain/0] iteration:38000  speed:535.46 MLUPS
# [  8154  INFO Subdomain/0] iteration:39000  speed:536.56 MLUPS
# [  8271  INFO Subdomain/0] iteration:40000  speed:536.02 MLUPS
# [  8449  INFO Subdomain/0] iteration:41000  speed:354.65 MLUPS
# [  8566  INFO Subdomain/0] iteration:42000  speed:536.18 MLUPS
# [  8684  INFO Subdomain/0] iteration:43000  speed:536.51 MLUPS
# [  8801  INFO Subdomain/0] iteration:44000  speed:536.14 MLUPS
# [  8918  INFO Subdomain/0] iteration:45000  speed:536.27 MLUPS
# [  9036  INFO Subdomain/0] iteration:46000  speed:536.33 MLUPS
# [  9153  INFO Subdomain/0] iteration:47000  speed:536.39 MLUPS
# [  9270  INFO Subdomain/0] iteration:48000  speed:536.22 MLUPS
# [  9388  INFO Subdomain/0] iteration:49000  speed:536.06 MLUPS
# [  9505  INFO Subdomain/0] iteration:50000  speed:535.71 MLUPS
# [  9685  INFO Subdomain/0] iteration:51000  speed:349.92 MLUPS
# [  9803  INFO Subdomain/0] iteration:52000  speed:535.27 MLUPS
# [  9920  INFO Subdomain/0] iteration:53000  speed:534.69 MLUPS
# [ 10038  INFO Subdomain/0] iteration:54000  speed:534.92 MLUPS
# [ 10156  INFO Subdomain/0] iteration:55000  speed:534.45 MLUPS
# [ 10273  INFO Subdomain/0] iteration:56000  speed:535.28 MLUPS
# [ 10391  INFO Subdomain/0] iteration:57000  speed:535.48 MLUPS
# [ 10509  INFO Subdomain/0] iteration:58000  speed:534.85 MLUPS
# [ 10626  INFO Subdomain/0] iteration:59000  speed:536.07 MLUPS
# [ 10743  INFO Subdomain/0] iteration:60000  speed:535.89 MLUPS
# [ 10924  INFO Subdomain/0] iteration:61000  speed:348.23 MLUPS
# [ 11042  INFO Subdomain/0] iteration:62000  speed:535.75 MLUPS
# [ 11159  INFO Subdomain/0] iteration:63000  speed:536.08 MLUPS
# [ 11276  INFO Subdomain/0] iteration:64000  speed:535.87 MLUPS
# [ 11394  INFO Subdomain/0] iteration:65000  speed:535.89 MLUPS
# [ 11511  INFO Subdomain/0] iteration:66000  speed:535.91 MLUPS
# [ 11629  INFO Subdomain/0] iteration:67000  speed:535.95 MLUPS
# [ 11746  INFO Subdomain/0] iteration:68000  speed:535.11 MLUPS
# [ 11864  INFO Subdomain/0] iteration:69000  speed:534.87 MLUPS
# [ 11982  INFO Subdomain/0] iteration:70000  speed:535.65 MLUPS
# [ 12161  INFO Subdomain/0] iteration:71000  speed:351.63 MLUPS
# [ 12278  INFO Subdomain/0] iteration:72000  speed:535.08 MLUPS
# [ 12396  INFO Subdomain/0] iteration:73000  speed:535.51 MLUPS
# [ 12513  INFO Subdomain/0] iteration:74000  speed:535.55 MLUPS
# [ 12631  INFO Subdomain/0] iteration:75000  speed:535.89 MLUPS
# [ 12748  INFO Subdomain/0] iteration:76000  speed:536.29 MLUPS
# [ 12865  INFO Subdomain/0] iteration:77000  speed:535.81 MLUPS
# [ 12983  INFO Subdomain/0] iteration:78000  speed:535.98 MLUPS
# [ 13100  INFO Subdomain/0] iteration:79000  speed:535.82 MLUPS
# [ 13218  INFO Subdomain/0] iteration:80000  speed:536.09 MLUPS
# [ 13395  INFO Subdomain/0] iteration:81000  speed:355.13 MLUPS
# [ 13513  INFO Subdomain/0] iteration:82000  speed:534.91 MLUPS
# [ 13630  INFO Subdomain/0] iteration:83000  speed:535.86 MLUPS
# [ 13747  INFO Subdomain/0] iteration:84000  speed:536.03 MLUPS
# [ 13865  INFO Subdomain/0] iteration:85000  speed:535.87 MLUPS
# [ 13982  INFO Subdomain/0] iteration:86000  speed:536.49 MLUPS
# [ 14100  INFO Subdomain/0] iteration:87000  speed:535.89 MLUPS
# [ 14217  INFO Subdomain/0] iteration:88000  speed:536.39 MLUPS
# [ 14335  INFO Subdomain/0] iteration:89000  speed:535.31 MLUPS
# [ 14452  INFO Subdomain/0] iteration:90000  speed:534.68 MLUPS
# [ 14633  INFO Subdomain/0] iteration:91000  speed:348.21 MLUPS
# [ 14750  INFO Subdomain/0] iteration:92000  speed:535.92 MLUPS
# [ 14868  INFO Subdomain/0] iteration:93000  speed:535.49 MLUPS
# [ 14985  INFO Subdomain/0] iteration:94000  speed:535.59 MLUPS
# [ 15103  INFO Subdomain/0] iteration:95000  speed:535.48 MLUPS
# [ 15221  INFO Subdomain/0] iteration:96000  speed:534.89 MLUPS
# [ 15338  INFO Subdomain/0] iteration:97000  speed:535.98 MLUPS
# [ 15456  INFO Subdomain/0] iteration:98000  speed:535.43 MLUPS
# [ 15573  INFO Subdomain/0] iteration:99000  speed:535.52 MLUPS
# [ 15691  INFO Subdomain/0] iteration:100000  speed:535.33 MLUPS
# [ 15753  INFO Subdomain/0] Simulation completed after 100000 iterations.

# %%
# !ls data/karman* -rtla|tail
# Out:
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 399211 Jan 27 06:59 data/karman.0.010000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 421359 Jan 27 06:59 data/karman.0.020000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 430350 Jan 27 06:59 data/karman.0.030000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 438398 Jan 27 07:00 data/karman.0.040000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 445800 Jan 27 07:00 data/karman.0.050000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 454664 Jan 27 07:00 data/karman.0.060000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 459327 Jan 27 07:00 data/karman.0.070000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 467397 Jan 27 07:00 data/karman.0.080000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 473792 Jan 27 07:00 data/karman.0.090000.npz
# -rw-r--r-- 1 ipython_user7202 ipython_user7202 479447 Jan 27 07:00 data/karman.0.100000.npz

# %%
data = np.load("data/karman.0.100000.npz")
data.files
data['v'][0].shape
vx,vy = data['v'] 
ny,nx = vx.shape
print "Body force:",0.5e-7
print "Max v:",np.nanmax(vx)
visc = 0.1
u_lb = np.nanmax(vx)
Re = u_lb*(20-1)/visc
dx = (1.0/(nx-1))
dt = 0.1/1.0*dx
print "Re:",Re,"dt:",dt,"dx:",dx
plt.imshow(np.sqrt(vx**2+vy**2),origin='top')
# Out:
# Body force: 5e-08
# Max v: 0.00432066
# Re: 0.820925603621 dt: 0.000196463654224 dx: 0.00196463654224

# %%
data = np.load("data/karman.0.100000.npz")
data.files
data['v'][0].shape
vx,vy = data['v'] 
ny,nx = vx.shape
print "Body force:",5e-7
print "Max v:",np.nanmax(vx)
visc = 0.1
u_lb = np.nanmax(vx)
Re = u_lb*(20-1)/visc
dx = (1.0/(nx-1))
dt = 0.1/1.0*dx
print "Re:",Re,"dt:",dt,"dx:",dx
plt.imshow(np.sqrt(vx**2+vy**2),origin='top')
# Out:
# Body force: 5e-07
# Max v: 0.0346317
# Re: 6.58001437783 dt: 0.000196463654224 dx: 0.00196463654224

# %%
data = np.load("data/karman.0.100000.npz")
data.files
data['v'][0].shape
vx,vy = data['v'] 
ny,nx = vx.shape
print "Body force:",15e-7
print "Max v:",np.nanmax(vx)
visc = 0.1
u_lb = np.nanmax(vx)
Re = u_lb*(20-1)/visc
dx = (1.0/(nx-1))
dt = 0.1/1.0*dx
print "Re:",Re,"dt:",dt,"dx:",dx
plt.imshow(np.sqrt(vx**2+vy**2),origin='top')
# Out:
# Body force: 1.5e-06
# Max v: 0.0913843
# Re: 17.3630125821 dt: 0.000196463654224 dx: 0.00196463654224

# %%
data = np.load("data/karman.0.100000.npz")
data.files
data['v'][0].shape
vx,vy = data['v'] 
ny,nx = vx.shape
print "Body force:",20e-7
print "Max v:",np.nanmax(vx)
visc = 0.1
u_lb = np.nanmax(vx)
Re = u_lb*(20-1)/visc
dx = (1.0/(nx-1))
dt = 0.1/1.0*dx
print "Re:",Re,"dt:",dt,"dx:",dx
plt.imshow(np.sqrt(vx**2+vy**2),origin='top')
# Out:
# Body force: 2e-06
# Max v: 0.112437
# Re: 21.3629695773 dt: 0.000196463654224 dx: 0.00196463654224

# %% [markdown]
# ## Analiza czasowej ewolucji przepływu
#
# Możemy łatwo przeanalizować przebieg symulacji z zapisanych pol makroskopowych na dysku. Poniższy kod:
#
#  - wczytuje wszystkie pliki pasujące do wzorca `data/karman.*.npz`
#  - korzystając z elementów interaktywnych w IPython, rysuje pole skalarne wybranej wielkości lub chwilewe linie  prądu w zadanym kroku czasowym
#
# `plt.imshow` jest najszybszą metodą wizualizacji pola skalarnego. `plt.streamlines` jest dużo wolniejsze, dlatego dla zapewnienia płynniejszego działania warto mieć kontrolę nad tym co jest rysowane. W przypadku większych pół należy użyć odpowieniego filtrowania za pomocą techniki `slice` by rysowanie jednek klatki nie trwało długo.

# %%
# %%time 
import glob
frames = []
s = (slice(None),slice(None))
#s = (slice(80,170,1),slice(20,220,1))
#s = (slice(None),slice(None,200,1))

for fn in sorted(glob.glob("data/karman.*.npz")):
    data =np.load(fn)
    vx,vy = data['v']
    rho = data['rho']
    vx, vy  = vx[s],vy[s]
    Dxvx,Dyvx = np.gradient(vx)
    Dxvy,Dyvy = np.gradient(vy)
    frames.append([vx, vy,Dyvx-Dxvy,rho])
# Out:
# CPU times: user 84 ms, sys: 8 ms, total: 92 ms
# Wall time: 92.7 ms

# %%
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
ny,nx = frames[0][0].shape
Y,X = np.mgrid[0:ny,0:nx]

@interact(ith=widgets.IntSlider(min=0,max=len(frames)-1),\
          figsize=widgets.IntSlider(min=0,max=20,value=10),\
          sel=widgets.Dropdown(values={'vx':0, 'vy': 1, 'rot v': 2,'rho':3},value=0),\
         stream=widgets.Checkbox())
def g(ith,figsize,sel,stream):
    
    plt.figure(figsize=(figsize,float(ny)/nx*figsize))
    vx,vy=frames[ith][:2]
    plt.xlim(1,nx-2)
    plt.ylim(1,ny-2) 
    plt.imshow(frames[ith][sel],origin='top')#,vmin=-0.1,vmax=0.1)
    if stream:
        plt.streamplot(X,Y,vx,vy,color='white',density=1)
    plt.axhline(y=ny/2, xmin=0, xmax=40, linewidth=1, color = 'k')
    print np.nanmax(vx)
    plt.show()
# Out:
# 0.0627408

# %%
from IPython.display import HTML
tab = """<table>
<tr>
<th>Body force</th>
<th>Zawirowanie</th>
<th>Załamanie "y"</th>
<th>Przepływ</th>
</tr>
<tr>
<td>0.5e-7</td>
<td>nie</td>
<td>nie</td>
<td>const.</td>
</tr>
<tr>
<td>5e-7</td>
<td>tak</td>
<td>nie</td>
<td>const.</td>
</tr>
<tr>
<td>15e-7</td>
<td>tak</td>
<td>tak</td>
<td>okresowy</td>
</tr>
<tr>
<td>20e-7</td>
<td>tak</td>
<td>tak</td>
<td>nieokresowy</td>
</tr>
</table>"""

print "Tabela wyników"
HTML(tab)
# Out:
# Tabela wyników
# <table>
# <tr>
# <th>Body force</th>
# <th>Zawirowanie</th>
# <th>Załamanie "y"</th>
# <th>Przepływ</th>
# </tr>
# <tr>
# <td>0.5e-7</td>
# <td>nie</td>
# <td>nie</td>
# <td>const.</td>
# </tr>
# <tr>
# <td>5e-7</td>
# <td>tak</td>
# <td>nie</td>
# <td>const.</td>
# </tr>
# <tr>
# <td>15e-7</td>
# <td>tak</td>
# <td>tak</td>
# <td>okresowy</td>
# </tr>
# <tr>
# <td>20e-7</td>
# <td>tak</td>
# <td>tak</td>
# <td>nieokresowy</td>
# </tr>
# </table>
